# %%
# %pylab inline
import sys
import glob
import os
import random

import numpy as np
import numpy.linalg as linalg
import numpy.random as rnd
from mpl_toolkits.mplot3d.axes3d import Axes3D

import GPy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Easydata GPLVM tests

# %% [markdown]
# ## Generating the data

# %%
sys.path.append('../tools/')
sys.path.append('..')
import easy_dataset
reload(easy_dataset)

Y, Xt = easy_dataset.gen_easydata(100, 1, 3)

# %% [markdown]
# After generating the data, plot in 3D and then each dimension as a function of the latent variable X:

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(Y[:, 0], Y[:, 1], Y[:, 2], 'x')
#ax.view_init(elev=60, azim=300)
ax.set_title('easydata')

fig, ax = plt.subplots(1, 3, figsize=(12, 4), dpi=180)
ax[0].plot(Xt, Y[:, 0], 'x')
ax[1].plot(Xt, Y[:, 1], 'x')
ax[2].plot(Xt, Y[:, 2], 'x')

# %% [markdown]
# ## Initialisation with PCA

# %%
def PCA(Y, input_dim):
	Z = numpy.linalg.svd(Y - Y.mean(axis=0), full_matrices=False)
	[X, W] = [Z[0][:, 0:input_dim], numpy.dot(numpy.diag(Z[1]), Z[2]).T[:, 0:input_dim]]
	v = X.std(axis=0)
	X /= v;
	W *= v;
	return X, W

X, W = PCA(Y, 2)

# %% [markdown]
# The main principle component of PCA manages to recover the correct latent coordinates (with perhaps a horizontal flip). In any case, the ordering is correctly found, which should give a very good initialisation for the GPLVM.

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4), dpi=180)
ax[0].plot(X[:, 0], Y[:, 0], 'x', label='PCA')
ax[0].plot(Xt, Y[:, 0], 'x', label='init')
ax[0].legend(loc=2)
ax[1].plot(X[:, 0], Y[:, 1], 'x')
ax[1].plot(Xt, Y[:, 1], 'x')
ax[2].plot(X[:, 0], Y[:, 2], 'x')
ax[2].plot(Xt, Y[:, 2], 'x')

plt.figure()
plt.plot(X[:, 0], X[:, 1], 'x')
plt.title('Display the full latent space')

# %% [markdown]
# We can also find the marginal likelihood of the model:

# %%
import MLtools
# Requires optimisation over beta, so maybe later.

# %% [markdown]
# ## GPy GPLVM results

# %% [markdown]
# We now run the GPy Bayesian GPLVM to see if sensible results are obtained. Sheffield seem to fix the noise while performing optimisation over (presumably) X, ard, Z etc.

# %%
# Parameters to adjust
Q = 2
num_inducing = 10

# %%
np.random.seed(0)

# Normalise data
Yn = Y - Y.mean(0)
Yn /= Yn.std(0)

# Set up model
rbf_comp = GPy.kern.rbf(Q, ARD=True)
kern = rbf_comp + GPy.kern.bias(Q, np.exp(-2)) + GPy.kern.white(Q, np.exp(-2))
m = GPy.models.BayesianGPLVM(Yn, Q, kernel=kern, num_inducing=10)
m['.*lengt'] = 1.               # ???
m['noise'] = Yn.var() / 100
m.ensure_default_constraints()

m.constrain_fixed('noise')
m.optimize('scg', messages=1, max_f_eval=100, gtol=.05)
print m.log_likelihood()
m.constrain_positive('noise')
m.optimize('scg', messages=1, max_f_eval=50, gtol=.05)
print m.log_likelihood()
# Out:
# Warning: re-constraining these parameters
# noise_variance
#  I      F              Scale          |g|
# 0001   6.267051e+03   1.000000e+00   4.074970e+07
# 0002   4.316789e+03   5.000000e-01   3.940073e+06
# 0003   2.924803e+03   2.500000e-01   6.436398e+05
# 0004   1.933264e+03   1.250000e-01   1.694779e+05
# 0005   1.740931e+03   6.250000e-02   5.827442e+05
# 0006   1.608862e+03   3.125000e-02   9.436143e+04
# 0019   1.980770e+02   3.814697e-06   7.088805e+01
# 0020   1.976010e+02   1.907349e-06   4.761897e+01
# 0021   1.971118e+02   9.536743e-07   9.040624e+01
# 0022   1.965482e+02   4.768372e-07   4.233080e+01
# 0023   1.959543e+02   2.384186e-07   1.242480e+02
# 0024   1.951870e+02   1.192093e-07   3.964993e+01
# 0025   1.943328e+02   5.960464e-08   2.038736e+02
# 0026   1.929255e+02   2.980232e-08   3.786193e+01
# 0027   1.907522e+02   1.490116e-08   6.525526e+02
# 0028   1.897856e+02   7.450581e-09   3.634128e+01
# 0029   1.888999e+02   3.725290e-09   2.169771e+02
# 0030   1.885615e+02   1.862645e-09   4.541865e+01
# 0031   1.882307e+02   9.313226e-10   6.614971e+01
# 0032   1.879142e+02   4.656613e-10   4.665571e+01
# 0033   1.876017e+02   2.328306e-10   6.157581e+01
# 0034   1.872948e+02   1.164153e-10   4.617117e+01
# 0035   1.869879e+02   5.820766e-11   6.274916e+01
# 0036   1.866855e+02   2.910383e-11   4.442508e+01
# 0037   1.863843e+02   1.455192e-11   6.280329e+01
# 0038   1.860856e+02   7.275958e-12   4.305819e+01
# 0039   1.857874e+02   3.637979e-12   6.391359e+01
# 0040   1.854913e+02   1.818989e-12   4.186310e+01
# 0041   1.851985e+02   9.094947e-13   6.317356e+01
# 0042   1.849060e+02   4.547474e-13   4.124267e+01
# 0043   1.846138e+02   2.273737e-13   6.511671e+01
# 0044   1.843228e+02   1.136868e-13   4.032294e+01
# 0045   1.840305e+02   5.684342e-14   6.708625e+01
# 0046   1.837391e+02   2.842171e-14   3.926172e+01
# 0047   1.834476e+02   1.421085e-14   6.846977e+01
# 0048   1.831566e+02   7.105427e-15   3.853418e+01
# 0048   1.831566e+02   3.552714e-15   7.003417e+01
#
# -183.156555258

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4), dpi=180)
ax[0].plot(m.X[:, 0], Y[:, 0], 'x', label='GPy')
ax[0].plot(X[:, 0], Y[:, 0], 'x', label='PCA')
ax[0].plot(Xt, Y[:, 0], 'x', label='init')
ax[0].legend(loc=2)

ax[1].plot(m.X[:, 0], Y[:, 1], 'x', label='GPy')
ax[1].plot(X[:, 0], Y[:, 1], 'x', label='PCA')
ax[1].plot(Xt, Y[:, 1], 'x', label='init')

ax[2].plot(m.X[:, 0], Y[:, 2], 'x', label='GPy')
ax[2].plot(X[:, 0], Y[:, 2], 'x', label='PCA')
ax[2].plot(Xt, Y[:, 2], 'x', label='init')

#fig, (latent_axes, sense_axes) = plt.subplots(1, 2)
#plt.sca(latent_axes)
plt.figure()
m.plot_latent()

plt.figure()

kern.plot_ARD()

# %% [markdown]
# ## Parallel GPLVM results

# %%
import scg_adapted
reload(scg_adapted)
execfile('easydata-pargplvm.py')
# Out:
# Creating ../easydata//embeddings//easy_4.embedding.npy with 28 points
# Creating ../easydata//embeddings//easy_4.variance.npy with 28 points
# Creating ../easydata//embeddings//easy_2.embedding.npy with 22 points
# Creating ../easydata//embeddings//easy_2.variance.npy with 22 points
# Creating ../easydata//embeddings//easy_3.embedding.npy with 27 points
# Creating ../easydata//embeddings//easy_3.variance.npy with 27 points
# Creating ../easydata//embeddings//easy_1.embedding.npy with 23 points
# Creating ../easydata//embeddings//easy_1.variance.npy with 23 points
# >>>>>>>>>>>>> Calling SCG_adapted
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#  I     F              Scale          |g|
# Starting optimisation for 100 iterations
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 001   5.087450e+02   1.000000e+00   3.969232e+03
# Calling local optimisation...
# Done! embeddings Map-Reduce took  0  seconds
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 002   5.087450e+02   9.719897e+08   4.514306e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 003   5.062347e+02   3.887959e+09   4.514306e+06
# 003   5.062347e+02   3.887959e+09   4.514306e+06
# Final global_statistics
# {'alpha': array([[ 0.14175884,  0.19104911]]), 'beta': array([[ 2.]]), 'Z': array([[-0.94616602,  1.42587793],
#        [-0.35089199, -0.95166032],
#        [-0.13999558,  1.66354653],
#        [ 1.46285455,  1.20208059],
#        [ 0.0992892 , -0.68878622],
#        [-1.89730543, -2.38786407],
#        [-1.13114722,  0.53608604],
#        [ 3.10677126, -0.48231848],
#        [ 3.652535  , -2.41674522],
#        [ 0.31521635,  0.09037432]]), 'sf2': array([[ 0.14869549]])}
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
# final F=-506.234747538
# >>>>>>>>>>>>> Calling SCG_adapted
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#  I     F              Scale          |g|
# Starting optimisation for 100 iterations
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 001   5.062347e+02   4.854343e+03   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 002   5.062347e+02   1.941737e+04   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 003   5.062347e+02   7.766949e+04   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 004   5.062347e+02   3.106780e+05   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 005   5.062347e+02   1.242712e+06   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 006   5.062347e+02   4.970847e+06   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 007   5.062347e+02   1.988339e+07   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 008   5.062347e+02   7.953356e+07   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 009   5.062347e+02   3.181342e+08   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 010   5.062347e+02   1.272537e+09   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 011   5.062347e+02   5.090148e+09   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 012   5.062347e+02   2.036059e+10   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 013   5.062347e+02   8.144236e+10   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 014   5.062347e+02   3.257694e+11   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 015   5.062347e+02   1.303078e+12   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 016   5.062347e+02   5.212311e+12   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 017   5.062347e+02   2.084924e+13   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 018   5.062347e+02   8.339698e+13   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 019   5.062347e+02   3.335879e+14   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 020   5.062347e+02   1.334352e+15   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 021   5.062347e+02   5.337407e+15   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 022   5.062347e+02   2.134963e+16   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 023   5.062347e+02   8.539851e+16   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 024   5.062347e+02   3.415940e+17   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 025   5.062347e+02   1.366376e+18   4.555754e+06
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
#
# 026   5.062347e+02   5.465504e+18   4.555754e+06
# 026   5.062347e+02   5.465504e+18   4.555754e+06
# Final global_statistics
# {'alpha': array([[ 0.14175884,  0.19104911]]), 'beta': array([[ 2.]]), 'Z': array([[-0.94616602,  1.42587793],
#        [-0.35089199, -0.95166032],
#        [-0.13999558,  1.66354653],
#        [ 1.46285455,  1.20208059],
#        [ 0.0992892 , -0.68878622],
#        [-1.89730543, -2.38786407],
#        [-1.13114722,  0.53608604],
#        [ 3.10677126, -0.48231848],
#        [ 3.652535  , -2.41674522],
#        [ 0.31521635,  0.09037432]]), 'sf2': array([[ 0.14869549]])}
# Done! statistics Map-Reduce took  0  seconds
# Done! global statistics took  0  seconds
# final F=-506.234747538

# %%
import show_embeddings
reload(show_embeddings)
class empty:
    pass
disp_opt = empty()
disp_opt.verbose = True
disp_opt.dimension = [0, 1]
disp_opt.output_dimension = [0, 1, 2]
disp_opt.plot2d = True
disp_opt.plot3d = False
args = [path]
pX = show_embeddings.run(disp_opt, args)

plt.figure()
plt.plot(m.X[:, 0], m.X[:, 1], 'x', label='GPy')
plt.plot(pX[:, 0], pX[:, 1], 'x', label='par-gplvm')
plt.legend()
plt.title('GPy result vs. our implementation')
# Out:
# Displaying X in '../easydata/'...
# alpha: [ 0.14175884  0.19104911]
# beta : 2.0
# sf2  : 0.148695486946
